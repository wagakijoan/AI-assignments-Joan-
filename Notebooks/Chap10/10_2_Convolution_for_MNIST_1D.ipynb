# %% [markdown]
# <a href="https://colab.research.google.com/github/wagakijoan/AI-assignments-Joan-/blob/main/Notebooks/Chap10/10_2_Convolution_for_MNIST_1D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 10.2: Convolution for MNIST-1D**
#
# This notebook investigates a 1D convolutional network for MNIST-1D as in figure 10.7 and 10.8a.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-e9i6sop3
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-e9i6sop3
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (26.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2026.6.17)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=e30657fa2adb36ead9678d9322d2201ac4d7c9e27b5dded1272fe42021ef7358
#   Stored in directory: /tmp/pip-ephem-wheel-cache-0d43cxo2/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# TODO Create a model with the following layers
# 1. Convolutional layer, (input=length 40 and 1 channel, kernel size 3, stride 2, padding="valid", 15 output channels )
# 2. ReLU
# 3. Convolutional layer, (input=length 19 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels )
# 4. ReLU
# 5. Convolutional layer, (input=length 9 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels)
# 6. ReLU
# 7. Flatten (converts 4x15) to length 60
# 8. Linear layer (input size = 60, output size = 10)
# References:
# https://pytorch.org/docs/1.13/generated/torch.nn.Conv1d.html?highlight=conv1d#torch.nn.Conv1d
# https://pytorch.org/docs/stable/generated/torch.nn.Flatten.html
# https://pytorch.org/docs/1.13/generated/torch.nn.Linear.html?highlight=linear#torch.nn.Linear

# NOTE THAT THE CONVOLUTIONAL LAYERS NEED TO TAKE THE NUMBER OF INPUT CHANNELS AS A PARAMETER
# AND NOT THE INPUT SIZE.

# Replace the following function:
model = nn.Sequential(
nn.Flatten(),
nn.Linear(40, 100),
nn.ReLU(),
nn.Linear(100, 100),
nn.ReLU(),
nn.Linear(100, 10))

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# create 100 dummy data points and store in data loader class
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long')).long()
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long')).long()

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch[:,None,:])
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train[:,None,:])
  pred_val = model(x_val[:,None,:])
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()

# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='validation')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('Part I: Validation Result %3.2f'%(errors_val[-1]))
ax.legend()
plt.show()
# Out:
# Epoch     0, train loss 1.573390, train error 60.65,  val loss 1.654908, percent error 65.60
# Epoch     1, train loss 1.310651, train error 47.88,  val loss 1.440050, percent error 55.70
# Epoch     2, train loss 1.126161, train error 39.95,  val loss 1.311537, percent error 51.50
# Epoch     3, train loss 1.006652, train error 35.95,  val loss 1.268491, percent error 48.10
# Epoch     4, train loss 0.905983, train error 32.72,  val loss 1.221600, percent error 46.70
# Epoch     5, train loss 0.802302, train error 27.78,  val loss 1.153643, percent error 43.70
# Epoch     6, train loss 0.713797, train error 25.43,  val loss 1.116048, percent error 43.00
# Epoch     7, train loss 0.627653, train error 20.72,  val loss 1.090830, percent error 41.20
# Epoch     8, train loss 0.593214, train error 20.53,  val loss 1.082943, percent error 37.80
# Epoch     9, train loss 0.530305, train error 17.72,  val loss 1.098920, percent error 40.10
# Epoch    10, train loss 0.494749, train error 16.72,  val loss 1.172106, percent error 41.30
# Epoch    11, train loss 0.443298, train error 15.50,  val loss 1.145071, percent error 40.20
# Epoch    12, train loss 0.376023, train error 12.22,  val loss 1.129970, percent error 38.40
# Epoch    13, train loss 0.316412, train error 9.55,  val loss 1.158264, percent error 38.50
# Epoch    14, train loss 0.305851, train error 9.70,  val loss 1.223048, percent error 40.00
# Epoch    15, train loss 0.251648, train error 7.53,  val loss 1.211783, percent error 38.50
# Epoch    16, train loss 0.198945, train error 5.25,  val loss 1.234781, percent error 38.70
# Epoch    17, train loss 0.209021, train error 6.10,  val loss 1.250169, percent error 37.40
# Epoch    18, train loss 0.194004, train error 5.80,  val loss 1.359520, percent error 37.90
# Epoch    19, train loss 0.137009, train error 3.05,  val loss 1.282637, percent error 37.00
# Epoch    20, train loss 0.080990, train error 0.60,  val loss 1.250392, percent error 34.60
# Epoch    21, train loss 0.065650, train error 0.30,  val loss 1.279746, percent error 36.10
# Epoch    22, train loss 0.056804, train error 0.12,  val loss 1.287464, percent error 35.70
# Epoch    23, train loss 0.049557, train error 0.03,  val loss 1.321575, percent error 35.70
# Epoch    24, train loss 0.045776, train error 0.03,  val loss 1.351140, percent error 36.70
# Epoch    25, train loss 0.041221, train error 0.00,  val loss 1.371504, percent error 36.00
# Epoch    26, train loss 0.038250, train error 0.00,  val loss 1.377750, percent error 36.20
# Epoch    27, train loss 0.034850, train error 0.00,  val loss 1.403009, percent error 36.40
# Epoch    28, train loss 0.031408, train error 0.00,  val loss 1.417506, percent error 36.10
# Epoch    29, train loss 0.029484, train error 0.00,  val loss 1.431962, percent error 36.30
# Epoch    30, train loss 0.027398, train error 0.00,  val loss 1.455236, percent error 36.20
# Epoch    31, train loss 0.025496, train error 0.00,  val loss 1.466737, percent error 36.10
# Epoch    32, train loss 0.024312, train error 0.00,  val loss 1.481036, percent error 36.10
# Epoch    33, train loss 0.022896, train error 0.00,  val loss 1.487177, percent error 35.90
# Epoch    34, train loss 0.021354, train error 0.00,  val loss 1.508815, percent error 35.40
# Epoch    35, train loss 0.020129, train error 0.00,  val loss 1.520775, percent error 36.00
# Epoch    36, train loss 0.019358, train error 0.00,  val loss 1.538207, percent error 35.70
# Epoch    37, train loss 0.018153, train error 0.00,  val loss 1.543920, percent error 36.10
# Epoch    38, train loss 0.017163, train error 0.00,  val loss 1.557571, percent error 36.20
# Epoch    39, train loss 0.016507, train error 0.00,  val loss 1.577413, percent error 36.50
# Epoch    40, train loss 0.015786, train error 0.00,  val loss 1.576285, percent error 36.50
# Epoch    41, train loss 0.015437, train error 0.00,  val loss 1.580183, percent error 36.60
# Epoch    42, train loss 0.015083, train error 0.00,  val loss 1.585668, percent error 36.40
# Epoch    43, train loss 0.014756, train error 0.00,  val loss 1.593835, percent error 36.70
# Epoch    44, train loss 0.014481, train error 0.00,  val loss 1.598649, percent error 36.60
# Epoch    45, train loss 0.014255, train error 0.00,  val loss 1.602717, percent error 36.60
# Epoch    46, train loss 0.014011, train error 0.00,  val loss 1.605717, percent error 36.30
# Epoch    47, train loss 0.013760, train error 0.00,  val loss 1.616981, percent error 36.30
# Epoch    48, train loss 0.013394, train error 0.00,  val loss 1.615824, percent error 36.60
# Epoch    49, train loss 0.013165, train error 0.00,  val loss 1.621743, percent error 36.50
# Epoch    50, train loss 0.012960, train error 0.00,  val loss 1.626992, percent error 36.30
# Epoch    51, train loss 0.012684, train error 0.00,  val loss 1.630937, percent error 36.40
# Epoch    52, train loss 0.012480, train error 0.00,  val loss 1.638674, percent error 36.70
# Epoch    53, train loss 0.012255, train error 0.00,  val loss 1.639679, percent error 36.70
# Epoch    54, train loss 0.012074, train error 0.00,  val loss 1.645509, percent error 36.40
# Epoch    55, train loss 0.011852, train error 0.00,  val loss 1.652653, percent error 36.70
# Epoch    56, train loss 0.011642, train error 0.00,  val loss 1.654486, percent error 36.60
# Epoch    57, train loss 0.011475, train error 0.00,  val loss 1.660774, percent error 36.30
# Epoch    58, train loss 0.011257, train error 0.00,  val loss 1.664372, percent error 36.40
# Epoch    59, train loss 0.011137, train error 0.00,  val loss 1.668369, percent error 36.50
# Epoch    60, train loss 0.010972, train error 0.00,  val loss 1.668821, percent error 36.40
# Epoch    61, train loss 0.010884, train error 0.00,  val loss 1.672661, percent error 36.50
# Epoch    62, train loss 0.010795, train error 0.00,  val loss 1.674120, percent error 36.60
# Epoch    63, train loss 0.010721, train error 0.00,  val loss 1.675802, percent error 36.40
# Epoch    64, train loss 0.010628, train error 0.00,  val loss 1.678400, percent error 36.50
# Epoch    65, train loss 0.010548, train error 0.00,  val loss 1.680213, percent error 36.50
# Epoch    66, train loss 0.010476, train error 0.00,  val loss 1.681849, percent error 36.60
# Epoch    67, train loss 0.010398, train error 0.00,  val loss 1.685302, percent error 36.70
# Epoch    68, train loss 0.010320, train error 0.00,  val loss 1.687076, percent error 36.30
# Epoch    69, train loss 0.010235, train error 0.00,  val loss 1.688059, percent error 36.50
# Epoch    70, train loss 0.010170, train error 0.00,  val loss 1.691159, percent error 36.30
# Epoch    71, train loss 0.010094, train error 0.00,  val loss 1.692350, percent error 36.70
# Epoch    72, train loss 0.010014, train error 0.00,  val loss 1.693702, percent error 36.50
# Epoch    73, train loss 0.009941, train error 0.00,  val loss 1.696384, percent error 36.50
# Epoch    74, train loss 0.009873, train error 0.00,  val loss 1.699039, percent error 36.30
# Epoch    75, train loss 0.009797, train error 0.00,  val loss 1.699964, percent error 36.50
# Epoch    76, train loss 0.009734, train error 0.00,  val loss 1.700827, percent error 36.40
# Epoch    77, train loss 0.009659, train error 0.00,  val loss 1.704161, percent error 36.50
# Epoch    78, train loss 0.009594, train error 0.00,  val loss 1.705989, percent error 36.40
# Epoch    79, train loss 0.009527, train error 0.00,  val loss 1.707293, percent error 36.60
# Epoch    80, train loss 0.009486, train error 0.00,  val loss 1.707773, percent error 36.50
# Epoch    81, train loss 0.009454, train error 0.00,  val loss 1.709068, percent error 36.50
# Epoch    82, train loss 0.009420, train error 0.00,  val loss 1.710267, percent error 36.40
# Epoch    83, train loss 0.009388, train error 0.00,  val loss 1.710424, percent error 36.50
# Epoch    84, train loss 0.009355, train error 0.00,  val loss 1.711589, percent error 36.40
# Epoch    85, train loss 0.009323, train error 0.00,  val loss 1.713072, percent error 36.50
# Epoch    86, train loss 0.009290, train error 0.00,  val loss 1.713598, percent error 36.40
# Epoch    87, train loss 0.009260, train error 0.00,  val loss 1.714615, percent error 36.50
# Epoch    88, train loss 0.009227, train error 0.00,  val loss 1.715805, percent error 36.50
# Epoch    89, train loss 0.009198, train error 0.00,  val loss 1.715817, percent error 36.50
# Epoch    90, train loss 0.009166, train error 0.00,  val loss 1.717694, percent error 36.50
# Epoch    91, train loss 0.009135, train error 0.00,  val loss 1.718132, percent error 36.40
# Epoch    92, train loss 0.009104, train error 0.00,  val loss 1.719367, percent error 36.50
# Epoch    93, train loss 0.009073, train error 0.00,  val loss 1.720251, percent error 36.50
# Epoch    94, train loss 0.009043, train error 0.00,  val loss 1.721066, percent error 36.50
# Epoch    95, train loss 0.009012, train error 0.00,  val loss 1.722286, percent error 36.50
# Epoch    96, train loss 0.008983, train error 0.00,  val loss 1.723515, percent error 36.50
# Epoch    97, train loss 0.008952, train error 0.00,  val loss 1.724044, percent error 36.50
# Epoch    98, train loss 0.008923, train error 0.00,  val loss 1.724574, percent error 36.50
# Epoch    99, train loss 0.008895, train error 0.00,  val loss 1.725229, percent error 36.50
