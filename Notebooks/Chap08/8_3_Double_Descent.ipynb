# %% [markdown]
# <a href="https://colab.research.google.com/github/wagakijoan/AI-assignments-Joan-/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-33fi1boo
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-33fi1boo
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (26.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2026.6.17)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=fa8de397c889c3ad3a2943e7ab1140fa307ca5a346b9190b49817aade706c36e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-9nzq00oj/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TODO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.299627, train error 88.30,  test loss 2.299792, test error 88.57
# Epoch   100, train loss 1.903674, train error 70.47,  test loss 1.750881, test error 68.38
# Epoch   200, train loss 1.894491, train error 69.90,  test loss 1.738790, test error 68.43
# Epoch   300, train loss 1.887025, train error 70.43,  test loss 1.723458, test error 67.68
# Epoch   400, train loss 1.873333, train error 69.57,  test loss 1.713888, test error 66.18
# Epoch   500, train loss 1.865004, train error 68.40,  test loss 1.700150, test error 66.05
# Epoch   600, train loss 1.866047, train error 68.82,  test loss 1.709186, test error 66.28
# Epoch   700, train loss 1.862196, train error 69.72,  test loss 1.701609, test error 65.72
# Epoch   800, train loss 1.866199, train error 68.62,  test loss 1.699806, test error 65.32
# Epoch   900, train loss 1.864104, train error 68.50,  test loss 1.698353, test error 65.40
# Training model with   4 hidden variables
# Epoch     0, train loss 2.301612, train error 89.88,  test loss 2.302219, test error 89.50
# Epoch   100, train loss 1.721540, train error 62.20,  test loss 1.523029, test error 58.67
# Epoch   200, train loss 1.700278, train error 62.72,  test loss 1.498448, test error 57.90
# Epoch   300, train loss 1.692534, train error 61.62,  test loss 1.501938, test error 57.78
# Epoch   400, train loss 1.687847, train error 61.47,  test loss 1.504959, test error 57.72
# Epoch   500, train loss 1.688443, train error 61.85,  test loss 1.498643, test error 58.03
# Epoch   600, train loss 1.687521, train error 61.65,  test loss 1.507013, test error 57.75
# Epoch   700, train loss 1.682909, train error 61.10,  test loss 1.504203, test error 58.17
# Epoch   800, train loss 1.685885, train error 61.65,  test loss 1.513451, test error 58.58
# Epoch   900, train loss 1.683187, train error 61.72,  test loss 1.502119, test error 57.83
# Training model with   6 hidden variables
# Epoch     0, train loss 2.295341, train error 87.15,  test loss 2.301017, test error 87.80
# Epoch   100, train loss 1.675735, train error 59.97,  test loss 1.493188, test error 57.47
# Epoch   200, train loss 1.643753, train error 58.80,  test loss 1.468539, test error 56.12
# Epoch   300, train loss 1.625437, train error 58.25,  test loss 1.443813, test error 56.28
# Epoch   400, train loss 1.607108, train error 57.47,  test loss 1.440818, test error 55.88
# Epoch   500, train loss 1.600848, train error 56.80,  test loss 1.444970, test error 56.25
# Epoch   600, train loss 1.597749, train error 57.25,  test loss 1.445946, test error 55.38
# Epoch   700, train loss 1.598732, train error 56.90,  test loss 1.451331, test error 55.85
# Epoch   800, train loss 1.592848, train error 56.53,  test loss 1.440236, test error 54.90
# Epoch   900, train loss 1.597336, train error 57.05,  test loss 1.454165, test error 56.05
# Training model with   8 hidden variables
# Epoch     0, train loss 2.244277, train error 84.50,  test loss 2.219828, test error 82.50
# Epoch   100, train loss 1.649077, train error 58.50,  test loss 1.479600, test error 56.78
# Epoch   200, train loss 1.559867, train error 53.80,  test loss 1.385279, test error 52.62
# Epoch   300, train loss 1.538818, train error 53.92,  test loss 1.389380, test error 54.47
# Epoch   400, train loss 1.529442, train error 54.10,  test loss 1.395550, test error 54.20
# Epoch   500, train loss 1.520990, train error 53.40,  test loss 1.399435, test error 54.45
# Epoch   600, train loss 1.520674, train error 53.85,  test loss 1.405013, test error 54.55
# Epoch   700, train loss 1.511333, train error 53.67,  test loss 1.405084, test error 54.45
# Epoch   800, train loss 1.502940, train error 53.50,  test loss 1.402668, test error 54.35
# Epoch   900, train loss 1.496166, train error 52.70,  test loss 1.408139, test error 53.83
# Training model with  10 hidden variables
# Epoch     0, train loss 2.181685, train error 79.50,  test loss 2.156938, test error 78.40
# Epoch   100, train loss 1.433870, train error 48.55,  test loss 1.245120, test error 46.25
# Epoch   200, train loss 1.397191, train error 47.10,  test loss 1.235554, test error 45.78
# Epoch   300, train loss 1.378547, train error 46.28,  test loss 1.242971, test error 46.72
# Epoch   400, train loss 1.370814, train error 46.62,  test loss 1.241653, test error 46.35
# Epoch   500, train loss 1.360846, train error 46.17,  test loss 1.247178, test error 46.58
# Epoch   600, train loss 1.357758, train error 46.17,  test loss 1.252898, test error 46.72
# Epoch   700, train loss 1.357247, train error 46.25,  test loss 1.261326, test error 46.67
# Epoch   800, train loss 1.351561, train error 45.90,  test loss 1.265548, test error 47.00
# Epoch   900, train loss 1.350805, train error 46.15,  test loss 1.268664, test error 46.53
# Training model with  14 hidden variables
# Epoch     0, train loss 2.117380, train error 79.68,  test loss 2.072346, test error 79.20
# Epoch   100, train loss 1.435107, train error 48.92,  test loss 1.360830, test error 51.33
# Epoch   200, train loss 1.340664, train error 44.75,  test loss 1.308892, test error 48.50
# Epoch   300, train loss 1.312080, train error 45.30,  test loss 1.322382, test error 48.08
# Epoch   400, train loss 1.296342, train error 44.08,  test loss 1.342318, test error 48.92
# Epoch   500, train loss 1.282554, train error 43.72,  test loss 1.353043, test error 48.88
# Epoch   600, train loss 1.280815, train error 44.00,  test loss 1.368847, test error 49.60
# Epoch   700, train loss 1.271527, train error 43.03,  test loss 1.364933, test error 49.92
# Epoch   800, train loss 1.261020, train error 42.85,  test loss 1.378758, test error 50.30
# Epoch   900, train loss 1.260430, train error 43.30,  test loss 1.394369, test error 50.12
# Training model with  18 hidden variables
# Epoch     0, train loss 2.202592, train error 81.25,  test loss 2.186026, test error 81.22
# Epoch   100, train loss 1.347405, train error 44.75,  test loss 1.304034, test error 48.55
# Epoch   200, train loss 1.239037, train error 41.25,  test loss 1.310945, test error 48.55
# Epoch   300, train loss 1.199951, train error 41.15,  test loss 1.356345, test error 49.65
# Epoch   400, train loss 1.168194, train error 39.47,  test loss 1.393991, test error 49.53
# Epoch   500, train loss 1.154724, train error 39.08,  test loss 1.437829, test error 51.08
# Epoch   600, train loss 1.150163, train error 39.47,  test loss 1.462801, test error 50.12
# Epoch   700, train loss 1.136551, train error 39.10,  test loss 1.484733, test error 50.47
# Epoch   800, train loss 1.117791, train error 38.83,  test loss 1.505481, test error 50.45
# Epoch   900, train loss 1.122570, train error 38.90,  test loss 1.521093, test error 51.97
# Training model with  22 hidden variables
# Epoch     0, train loss 2.218138, train error 83.22,  test loss 2.194605, test error 82.82
# Epoch   100, train loss 1.299005, train error 43.42,  test loss 1.302915, test error 48.62
# Epoch   200, train loss 1.178275, train error 38.45,  test loss 1.403824, test error 49.12
# Epoch   300, train loss 1.125224, train error 36.72,  test loss 1.473202, test error 50.70
# Epoch   400, train loss 1.103693, train error 36.90,  test loss 1.544966, test error 51.33
# Epoch   500, train loss 1.077989, train error 35.88,  test loss 1.618064, test error 51.35
# Epoch   600, train loss 1.050028, train error 35.30,  test loss 1.666577, test error 51.88
# Epoch   700, train loss 1.028510, train error 33.62,  test loss 1.746534, test error 52.28
# Epoch   800, train loss 1.025419, train error 33.90,  test loss 1.798743, test error 52.25
# Epoch   900, train loss 1.006614, train error 33.65,  test loss 1.848649, test error 52.08
# Training model with  26 hidden variables
# Epoch     0, train loss 2.179896, train error 81.68,  test loss 2.180210, test error 81.47
# Epoch   100, train loss 1.186324, train error 39.00,  test loss 1.359500, test error 48.45
# Epoch   200, train loss 1.015882, train error 33.25,  test loss 1.419739, test error 48.28
# Epoch   300, train loss 0.948447, train error 31.62,  test loss 1.546050, test error 49.97
# Epoch   400, train loss 0.923545, train error 30.60,  test loss 1.639546, test error 50.97
# Epoch   500, train loss 0.869704, train error 28.68,  test loss 1.680426, test error 50.67
# Epoch   600, train loss 0.858088, train error 29.03,  test loss 1.755559, test error 50.70
# Epoch   700, train loss 0.826591, train error 27.65,  test loss 1.809274, test error 51.65
# Epoch   800, train loss 0.842255, train error 28.78,  test loss 1.852969, test error 51.05
# Epoch   900, train loss 0.821701, train error 27.97,  test loss 1.905955, test error 51.88
# Training model with  30 hidden variables
# Epoch     0, train loss 2.125600, train error 80.45,  test loss 2.078851, test error 78.47
# Epoch   100, train loss 1.131866, train error 37.03,  test loss 1.386077, test error 50.20
# Epoch   200, train loss 0.945440, train error 30.62,  test loss 1.566265, test error 51.55
# Epoch   300, train loss 0.837291, train error 27.22,  test loss 1.738337, test error 52.20
# Epoch   400, train loss 0.784588, train error 25.28,  test loss 1.901570, test error 52.25
# Epoch   500, train loss 0.742739, train error 24.90,  test loss 2.082858, test error 53.60
# Epoch   600, train loss 0.706984, train error 24.03,  test loss 2.229384, test error 53.25
# Epoch   700, train loss 0.696139, train error 23.30,  test loss 2.411973, test error 54.47
# Epoch   800, train loss 0.684575, train error 23.53,  test loss 2.474084, test error 53.83
# Epoch   900, train loss 0.660299, train error 23.07,  test loss 2.616488, test error 54.55
# Training model with  35 hidden variables
# Epoch     0, train loss 2.103307, train error 78.43,  test loss 2.055658, test error 77.90
# Epoch   100, train loss 1.024705, train error 34.50,  test loss 1.408715, test error 50.12
# Epoch   200, train loss 0.794042, train error 26.57,  test loss 1.704706, test error 51.88
# Epoch   300, train loss 0.712392, train error 24.82,  test loss 2.055421, test error 53.47
# Epoch   400, train loss 0.615451, train error 20.65,  test loss 2.447286, test error 55.60
# Epoch   500, train loss 0.567060, train error 18.82,  test loss 2.703612, test error 54.97
# Epoch   600, train loss 0.542888, train error 18.60,  test loss 2.925811, test error 55.30
# Epoch   700, train loss 0.494572, train error 15.88,  test loss 3.249414, test error 56.85
# Epoch   800, train loss 0.519190, train error 17.65,  test loss 3.501320, test error 57.10
# Epoch   900, train loss 0.507794, train error 17.82,  test loss 3.638499, test error 56.55
# Training model with  40 hidden variables
# Epoch     0, train loss 2.171870, train error 80.57,  test loss 2.161235, test error 80.07
# Epoch   100, train loss 0.964080, train error 31.12,  test loss 1.474733, test error 50.90
# Epoch   200, train loss 0.683620, train error 22.18,  test loss 1.966131, test error 53.40
# Epoch   300, train loss 0.538556, train error 17.82,  test loss 2.531950, test error 54.58
# Epoch   400, train loss 0.443671, train error 14.07,  test loss 3.122384, test error 54.38
# Epoch   500, train loss 0.391158, train error 13.07,  test loss 3.889648, test error 56.92
# Epoch   600, train loss 0.311538, train error 9.93,  test loss 4.547961, test error 56.88
# Epoch   700, train loss 0.337295, train error 12.38,  test loss 5.295338, test error 57.67
# Epoch   800, train loss 0.294723, train error 9.90,  test loss 5.879635, test error 57.50
# Epoch   900, train loss 0.298885, train error 10.12,  test loss 6.502276, test error 58.10
# Training model with  45 hidden variables
# Epoch     0, train loss 2.099407, train error 78.22,  test loss 2.049472, test error 77.35
# Epoch   100, train loss 0.814036, train error 25.28,  test loss 1.537332, test error 49.38
# Epoch   200, train loss 0.463750, train error 13.65,  test loss 2.326180, test error 54.28
# Epoch   300, train loss 0.373610, train error 12.50,  test loss 3.430440, test error 56.65
# Epoch   400, train loss 0.259221, train error 8.62,  test loss 4.627683, test error 57.08
# Epoch   500, train loss 0.201957, train error 7.18,  test loss 5.755520, test error 56.97
# Epoch   600, train loss 0.207399, train error 7.75,  test loss 6.858822, test error 56.42
# Epoch   700, train loss 0.118955, train error 4.47,  test loss 7.713835, test error 56.15
# Epoch   800, train loss 0.224055, train error 7.35,  test loss 8.871903, test error 56.85
# Epoch   900, train loss 0.006889, train error 0.00,  test loss 9.585849, test error 56.65
# Training model with  50 hidden variables
# Epoch     0, train loss 2.092990, train error 77.75,  test loss 2.080952, test error 77.47
# Epoch   100, train loss 0.697772, train error 22.65,  test loss 1.548478, test error 50.22
# Epoch   200, train loss 0.347609, train error 10.50,  test loss 2.442579, test error 52.20
# Epoch   300, train loss 0.155409, train error 3.55,  test loss 3.845858, test error 53.78
# Epoch   400, train loss 0.035750, train error 0.03,  test loss 5.459955, test error 54.58
# Epoch   500, train loss 0.016822, train error 0.00,  test loss 6.496397, test error 55.08
# Epoch   600, train loss 0.009451, train error 0.00,  test loss 7.162704, test error 55.40
# Epoch   700, train loss 0.006588, train error 0.00,  test loss 7.670341, test error 55.20
# Epoch   800, train loss 0.005009, train error 0.00,  test loss 8.052953, test error 55.28
# Epoch   900, train loss 0.003976, train error 0.00,  test loss 8.374595, test error 55.55
# Training model with  55 hidden variables
# Epoch     0, train loss 2.038947, train error 75.12,  test loss 1.993244, test error 75.47
# Epoch   100, train loss 0.603462, train error 18.32,  test loss 1.717549, test error 51.60
# Epoch   200, train loss 0.214776, train error 5.12,  test loss 3.107763, test error 53.78
# Epoch   300, train loss 0.039380, train error 0.03,  test loss 4.827715, test error 54.38
# Epoch   400, train loss 0.013833, train error 0.00,  test loss 5.862347, test error 54.15
# Epoch   500, train loss 0.008169, train error 0.00,  test loss 6.496824, test error 54.60
# Epoch   600, train loss 0.005599, train error 0.00,  test loss 6.939472, test error 54.58
# Epoch   700, train loss 0.004206, train error 0.00,  test loss 7.297471, test error 54.75
# Epoch   800, train loss 0.003341, train error 0.00,  test loss 7.590341, test error 54.67
# Epoch   900, train loss 0.002738, train error 0.00,  test loss 7.825547, test error 54.83
# Training model with  60 hidden variables
# Epoch     0, train loss 2.036411, train error 75.53,  test loss 1.978662, test error 75.93
# Epoch   100, train loss 0.549423, train error 15.45,  test loss 1.688304, test error 49.95
# Epoch   200, train loss 0.118714, train error 1.43,  test loss 3.326529, test error 53.53
# Epoch   300, train loss 0.020797, train error 0.00,  test loss 4.681402, test error 54.05
# Epoch   400, train loss 0.009833, train error 0.00,  test loss 5.378463, test error 54.45
# Epoch   500, train loss 0.006178, train error 0.00,  test loss 5.836716, test error 54.55
# Epoch   600, train loss 0.004385, train error 0.00,  test loss 6.171628, test error 54.58
# Epoch   700, train loss 0.003388, train error 0.00,  test loss 6.439392, test error 54.50
# Epoch   800, train loss 0.002708, train error 0.00,  test loss 6.661694, test error 54.50
# Epoch   900, train loss 0.002246, train error 0.00,  test loss 6.849405, test error 54.53
# Training model with  70 hidden variables
# Epoch     0, train loss 2.050653, train error 77.32,  test loss 1.993950, test error 76.88
# Epoch   100, train loss 0.341631, train error 7.78,  test loss 1.943245, test error 51.12
# Epoch   200, train loss 0.030354, train error 0.00,  test loss 3.484228, test error 52.03
# Epoch   300, train loss 0.010480, train error 0.00,  test loss 4.244142, test error 52.28
# Epoch   400, train loss 0.005921, train error 0.00,  test loss 4.671373, test error 52.55
# Epoch   500, train loss 0.003994, train error 0.00,  test loss 4.964016, test error 52.58
# Epoch   600, train loss 0.002966, train error 0.00,  test loss 5.193518, test error 52.72
# Epoch   700, train loss 0.002332, train error 0.00,  test loss 5.377018, test error 52.72
# Epoch   800, train loss 0.001908, train error 0.00,  test loss 5.531636, test error 52.72
# Epoch   900, train loss 0.001604, train error 0.00,  test loss 5.665297, test error 52.70
# Training model with  80 hidden variables
# Epoch     0, train loss 2.015430, train error 74.97,  test loss 1.950432, test error 74.30
# Epoch   100, train loss 0.241039, train error 4.72,  test loss 2.021266, test error 50.83
# Epoch   200, train loss 0.019272, train error 0.00,  test loss 3.296004, test error 50.75
# Epoch   300, train loss 0.007886, train error 0.00,  test loss 3.818339, test error 51.05
# Epoch   400, train loss 0.004671, train error 0.00,  test loss 4.127459, test error 51.08
# Epoch   500, train loss 0.003252, train error 0.00,  test loss 4.350375, test error 51.05
# Epoch   600, train loss 0.002441, train error 0.00,  test loss 4.521541, test error 51.10
# Epoch   700, train loss 0.001938, train error 0.00,  test loss 4.661548, test error 51.15
# Epoch   800, train loss 0.001597, train error 0.00,  test loss 4.779301, test error 51.40
# Epoch   900, train loss 0.001350, train error 0.00,  test loss 4.881023, test error 51.35
# Training model with  90 hidden variables
# Epoch     0, train loss 2.037998, train error 76.32,  test loss 1.997260, test error 76.78
# Epoch   100, train loss 0.137022, train error 0.90,  test loss 2.214747, test error 52.08
# Epoch   200, train loss 0.014884, train error 0.00,  test loss 3.268774, test error 51.70
# Epoch   300, train loss 0.006565, train error 0.00,  test loss 3.696512, test error 51.58
# Epoch   400, train loss 0.004003, train error 0.00,  test loss 3.967432, test error 51.67
# Epoch   500, train loss 0.002811, train error 0.00,  test loss 4.159998, test error 51.70
# Epoch   600, train loss 0.002140, train error 0.00,  test loss 4.309980, test error 51.70
# Epoch   700, train loss 0.001711, train error 0.00,  test loss 4.433888, test error 51.70
# Epoch   800, train loss 0.001416, train error 0.00,  test loss 4.538124, test error 51.75
# Epoch   900, train loss 0.001202, train error 0.00,  test loss 4.629340, test error 51.80
# Training model with 100 hidden variables
# Epoch     0, train loss 1.983893, train error 74.80,  test loss 1.892618, test error 72.85
# Epoch   100, train loss 0.104071, train error 0.45,  test loss 2.138157, test error 49.35
# Epoch   200, train loss 0.012769, train error 0.00,  test loss 2.997078, test error 50.67
# Epoch   300, train loss 0.005842, train error 0.00,  test loss 3.358390, test error 50.85
# Epoch   400, train loss 0.003631, train error 0.00,  test loss 3.582608, test error 50.92
# Epoch   500, train loss 0.002579, train error 0.00,  test loss 3.746632, test error 50.80
# Epoch   600, train loss 0.001970, train error 0.00,  test loss 3.875503, test error 50.90
# Epoch   700, train loss 0.001581, train error 0.00,  test loss 3.979905, test error 50.92
# Epoch   800, train loss 0.001312, train error 0.00,  test loss 4.070459, test error 50.90
# Epoch   900, train loss 0.001116, train error 0.00,  test loss 4.147806, test error 50.95
# Training model with 120 hidden variables
# Epoch     0, train loss 1.976527, train error 73.43,  test loss 1.913521, test error 73.62
# Epoch   100, train loss 0.045706, train error 0.00,  test loss 2.232399, test error 50.83
# Epoch   200, train loss 0.008994, train error 0.00,  test loss 2.815044, test error 50.75
# Epoch   300, train loss 0.004506, train error 0.00,  test loss 3.080098, test error 50.50
# Epoch   400, train loss 0.002896, train error 0.00,  test loss 3.254235, test error 50.55
# Epoch   500, train loss 0.002090, train error 0.00,  test loss 3.381343, test error 50.58
# Epoch   600, train loss 0.001619, train error 0.00,  test loss 3.483628, test error 50.53
# Epoch   700, train loss 0.001311, train error 0.00,  test loss 3.567719, test error 50.58
# Epoch   800, train loss 0.001096, train error 0.00,  test loss 3.639359, test error 50.55
# Epoch   900, train loss 0.000937, train error 0.00,  test loss 3.702592, test error 50.53
# Training model with 140 hidden variables
# Epoch     0, train loss 1.946082, train error 72.53,  test loss 1.873216, test error 72.75
# Epoch   100, train loss 0.034954, train error 0.00,  test loss 2.233285, test error 50.65
# Epoch   200, train loss 0.008032, train error 0.00,  test loss 2.701976, test error 50.08
# Epoch   300, train loss 0.004139, train error 0.00,  test loss 2.928495, test error 50.33
# Epoch   400, train loss 0.002688, train error 0.00,  test loss 3.073772, test error 50.35
# Epoch   500, train loss 0.001956, train error 0.00,  test loss 3.182491, test error 50.40
# Epoch   600, train loss 0.001522, train error 0.00,  test loss 3.270316, test error 50.38
# Epoch   700, train loss 0.001236, train error 0.00,  test loss 3.342157, test error 50.58
# Epoch   800, train loss 0.001035, train error 0.00,  test loss 3.404219, test error 50.47
# Epoch   900, train loss 0.000887, train error 0.00,  test loss 3.458225, test error 50.35
# Training model with 160 hidden variables
# Epoch     0, train loss 1.940419, train error 71.12,  test loss 1.871713, test error 72.55
# Epoch   100, train loss 0.028313, train error 0.00,  test loss 2.142133, test error 49.45
# Epoch   200, train loss 0.007108, train error 0.00,  test loss 2.555577, test error 48.95
# Epoch   300, train loss 0.003743, train error 0.00,  test loss 2.760003, test error 48.97
# Epoch   400, train loss 0.002461, train error 0.00,  test loss 2.895822, test error 49.03
# Epoch   500, train loss 0.001802, train error 0.00,  test loss 2.998491, test error 49.00
# Epoch   600, train loss 0.001407, train error 0.00,  test loss 3.078108, test error 48.88
# Epoch   700, train loss 0.001146, train error 0.00,  test loss 3.147328, test error 49.03
# Epoch   800, train loss 0.000962, train error 0.00,  test loss 3.204634, test error 49.00
# Epoch   900, train loss 0.000826, train error 0.00,  test loss 3.254342, test error 49.08
# Training model with 180 hidden variables
# Epoch     0, train loss 1.926420, train error 69.90,  test loss 1.866223, test error 73.28
# Epoch   100, train loss 0.025165, train error 0.00,  test loss 2.013628, test error 48.28
# Epoch   200, train loss 0.006711, train error 0.00,  test loss 2.358728, test error 48.17
# Epoch   300, train loss 0.003571, train error 0.00,  test loss 2.532721, test error 48.33
# Epoch   400, train loss 0.002362, train error 0.00,  test loss 2.651114, test error 48.38
# Epoch   500, train loss 0.001736, train error 0.00,  test loss 2.738257, test error 48.35
# Epoch   600, train loss 0.001359, train error 0.00,  test loss 2.809167, test error 48.35
# Epoch   700, train loss 0.001108, train error 0.00,  test loss 2.868712, test error 48.28
# Epoch   800, train loss 0.000931, train error 0.00,  test loss 2.918818, test error 48.28
# Epoch   900, train loss 0.000800, train error 0.00,  test loss 2.963583, test error 48.25
# Training model with 200 hidden variables
# Epoch     0, train loss 1.923266, train error 71.45,  test loss 1.853400, test error 71.82
# Epoch   100, train loss 0.021326, train error 0.00,  test loss 2.026288, test error 47.72
# Epoch   200, train loss 0.006141, train error 0.00,  test loss 2.353994, test error 47.92
# Epoch   300, train loss 0.003332, train error 0.00,  test loss 2.517569, test error 47.90
# Epoch   400, train loss 0.002224, train error 0.00,  test loss 2.629065, test error 48.05
# Epoch   500, train loss 0.001644, train error 0.00,  test loss 2.713243, test error 48.15
# Epoch   600, train loss 0.001291, train error 0.00,  test loss 2.780610, test error 48.00
# Epoch   700, train loss 0.001056, train error 0.00,  test loss 2.836890, test error 48.00
# Epoch   800, train loss 0.000889, train error 0.00,  test loss 2.885278, test error 47.85
# Epoch   900, train loss 0.000765, train error 0.00,  test loss 2.927616, test error 47.88
# Training model with 250 hidden variables
# Epoch     0, train loss 1.897849, train error 68.93,  test loss 1.810564, test error 71.15
# Epoch   100, train loss 0.016857, train error 0.00,  test loss 1.906377, test error 46.85
# Epoch   200, train loss 0.005313, train error 0.00,  test loss 2.162135, test error 47.08
# Epoch   300, train loss 0.002955, train error 0.00,  test loss 2.295567, test error 47.03
# Epoch   400, train loss 0.001995, train error 0.00,  test loss 2.387227, test error 46.83
# Epoch   500, train loss 0.001485, train error 0.00,  test loss 2.457803, test error 46.78
# Epoch   600, train loss 0.001172, train error 0.00,  test loss 2.514171, test error 46.85
# Epoch   700, train loss 0.000962, train error 0.00,  test loss 2.561360, test error 46.80
# Epoch   800, train loss 0.000812, train error 0.00,  test loss 2.602545, test error 46.80
# Epoch   900, train loss 0.000701, train error 0.00,  test loss 2.637846, test error 46.72
# Training model with 300 hidden variables
# Epoch     0, train loss 1.893447, train error 70.20,  test loss 1.811447, test error 70.47
# Epoch   100, train loss 0.014618, train error 0.00,  test loss 1.846898, test error 46.15
# Epoch   200, train loss 0.004851, train error 0.00,  test loss 2.064708, test error 46.10
# Epoch   300, train loss 0.002748, train error 0.00,  test loss 2.183907, test error 46.10
# Epoch   400, train loss 0.001870, train error 0.00,  test loss 2.264537, test error 46.10
# Epoch   500, train loss 0.001398, train error 0.00,  test loss 2.326127, test error 45.92
# Epoch   600, train loss 0.001106, train error 0.00,  test loss 2.375848, test error 46.05
# Epoch   700, train loss 0.000911, train error 0.00,  test loss 2.417124, test error 45.85
# Epoch   800, train loss 0.000771, train error 0.00,  test loss 2.453025, test error 45.85
# Epoch   900, train loss 0.000666, train error 0.00,  test loss 2.484698, test error 45.80
# Training model with 400 hidden variables
# Epoch     0, train loss 1.838425, train error 65.88,  test loss 1.774393, test error 68.60
# Epoch   100, train loss 0.011741, train error 0.00,  test loss 1.785684, test error 45.70
# Epoch   200, train loss 0.004197, train error 0.00,  test loss 1.960509, test error 45.40
# Epoch   300, train loss 0.002433, train error 0.00,  test loss 2.058685, test error 45.53
# Epoch   400, train loss 0.001677, train error 0.00,  test loss 2.126946, test error 45.55
# Epoch   500, train loss 0.001264, train error 0.00,  test loss 2.179434, test error 45.42
# Epoch   600, train loss 0.001007, train error 0.00,  test loss 2.221527, test error 45.50
# Epoch   700, train loss 0.000832, train error 0.00,  test loss 2.257210, test error 45.55
# Epoch   800, train loss 0.000706, train error 0.00,  test loss 2.287846, test error 45.50
# Epoch   900, train loss 0.000611, train error 0.00,  test loss 2.315103, test error 45.45

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
